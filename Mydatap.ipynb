# %% [markdown]
# <a href="https://colab.research.google.com/github/wajahatsiddique123-ah/Exploratory-Data-Analysis-EDA-/blob/main/Mydatap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
df=pd.read_excel("/content/BusinessData.xlsx")
print(f"\nTop 2 data :\n",df.head(2))
print(f"\nLast Two Data :\n",df.tail(2))
print(f"\nInformation of Data :\n")
print(df.info())
print(f"\nData by statiscally:\n",df.describe())

clean_df=df.replace(["Null","nan"],0).fillna(0)
 #clean_df['Profit']=pd.to_numeric(clean_df['Profit'])
print(f"\n===== Updated data ====\n")
print(clean_df)
print(f"\n==== Visualize the Data by Bar Graph======\n")

plt.figure(figsize=(7,4))
plt.bar(clean_df['Month'],clean_df['Profit'],color="blue",edgecolor="black")
plt.plot(['Jan','Dec'],[50,110],color="red",linewidth=2,label="Trend Line")
for index,row in clean_df.iterrows():
  if row['Profit']==0:
    plt.text(row['Month'],2,"Missing",color="red",fontsize=9)
plt.title("Month And their Profit")
plt.xlabel("Month")
plt.ylabel("Profit")
plt.show()

print(f"\n====== Summary =====")
print(
    "I compare the months and their profit of this data and clearly shows that the profit is increasing everying month"
    " but in my data you see that (April,July,Dec) profit can not show because the data of these months are null so i put 0 on them "
    "and in Final i say that according to data the profit is increasing in upcoming months because of trends and patterns "
)
# Out:
# Top 2 data :
#    Month Sales Orders Expenses Profit
# 0   Jan   120     30       70     50
# 1   Feb  Null     35       80     55
#
# Last Two Data :
#     Month Sales Orders Expenses Profit
# 10   Nov   260     70      150    110
# 11   Dec   npn     75      160   Null
#
# Information of Data :
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Month     12 non-null     object
#  1   Sales     12 non-null     object
#  2   Orders    12 non-null     object
#  3   Expenses  12 non-null     object
#  4   Profit    12 non-null     object
# dtypes: object(5)
# memory usage: 612.0+ bytes
# None
#
# Data by statiscally:
#         Month Sales Orders  Expenses Profit
# count     12    12     12        12     12
# unique    12    10     11        12     10
# top      Jan  Null   Null        70   Null
# freq       1     2      2         1      3
#
# ...
